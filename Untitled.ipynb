# %%
import numpy as np
import pandas as pd
import seaborn as sns
import io
import statsmodels.formula.api as smf
import scipy.stats as stats

# %%
sleep_df = pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/sleep75.csv')
sleep_df
# Out:
#      age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0     32      0     1  0.000000  0.000000    12        0       0     1   3529
# 1     31      0     2  0.000000  0.000000    14     9500       1     1   2140
# 2     44      0     3  0.000000  0.000000    17    42500       1     1   4595
# 3     30      0     4  0.000000  0.000000    12    42500       1     1   3211
# 4     64      0     5  0.000000  0.000000    14     2500       1     1   4052
# ..   ...    ...   ...       ...       ...   ...      ...     ...   ...    ...
# 701   45      0   702  0.182331  0.030075    12     5500       1     0   5069
# 702   34      0   703  0.182331  0.030075    10     2500       0     0   5885
# 703   37      0   704  0.182331  0.030075    12     3500       1     0   4719
# 704   54      0   705  0.182331  0.030075    17    32500       1     0   5149
# 705   30      0   706  0.182331  0.030075    16     6750       1     0   4747
#
# ...

# %%
sleep_df
# Out:
#      age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0     32      0     1  0.000000  0.000000    12        0       0     1   3529
# 1     31      0     2  0.000000  0.000000    14     9500       1     1   2140
# 2     44      0     3  0.000000  0.000000    17    42500       1     1   4595
# 3     30      0     4  0.000000  0.000000    12    42500       1     1   3211
# 4     64      0     5  0.000000  0.000000    14     2500       1     1   4052
# ..   ...    ...   ...       ...       ...   ...      ...     ...   ...    ...
# 701   45      0   702  0.182331  0.030075    12     5500       1     0   5069
# 702   34      0   703  0.182331  0.030075    10     2500       0     0   5885
# 703   37      0   704  0.182331  0.030075    12     3500       1     0   4719
# 704   54      0   705  0.182331  0.030075    17    32500       1     0   5149
# 705   30      0   706  0.182331  0.030075    16     6750       1     0   4747
#
# ...

# %%
# Определим датафрейм
sleep_df = pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/sleep75.csv')
sleep_df['sleep60'] = sleep_df['sleep']/60 # создадим столбец часов времени
# Отфильтруем датафрейм по гендерному признаку
sleep_male = sleep_df[sleep_df['male']==1] # Датафрейм для мужчин
sleep_female = sleep_df[sleep_df['male']==0] # Датафрейм дла женщин

# %%
alpha=0.01
F_cr = stats.f.ppf(1-alpha, 7, 706-7)
F_cr
# Out:
# 2.664892952419547

# %% [markdown]
# Вывод Fobs < Fcr данные согласуются с нулевой гипотезой Ho.Структурные различия незначимы.

# %%
sns.lmplot(data=sleep_df, y='sleep', x='totwrk')

# %%
sns.pairplot(sleep_df)
<seaborn.axisgrid.PairGrid at 0x1c72
# Out:
#   Cell In[11], line 2
#     <seaborn.axisgrid.PairGrid at 0x1c72
#     ^
# SyntaxError: invalid syntax

# %%
data_string = '''totwrk                       -0.169***         
                              (0.018)          
                                               
age                           2.689*           
                              (1.469)          
                                               
south                        101.568**         
                             (41.837)          
                                               
male                         87.669**          
                             (35.104)          
                                               
smsa                         -54.748*          
                             (33.123)          
                                               
yngkid                        -13.962          
                             (50.341)          
                                               
marr                          31.211           
                             (42.233)          
                                               
Constant                    3450.913***        
                             (80.726)        '''

# %%
data_string.strip().split()
# Out:
# ['totwrk',
#  '-0.169***',
#  '(0.018)',
#  'age',
#  '2.689*',
#  '(1.469)',
#  'south',
#  '101.568**',
#  '(41.837)',
#  'male',
#  '87.669**',
#  '(35.104)',
#  'smsa',
#  '-54.748*',
#  '(33.123)',
#  'yngkid',
#  '-13.962',
#  '(50.341)',
#  'marr',
#  '31.211',
#  '(42.233)',
#  'Constant',
#  '3450.913***',
#  '(80.726)']

# %%
np.reshape (data_string.strip().split(),(8,3))
# Out:
# array([['totwrk', '-0.169***', '(0.018)'],
#        ['age', '2.689*', '(1.469)'],
#        ['south', '101.568**', '(41.837)'],
#        ['male', '87.669**', '(35.104)'],
#        ['smsa', '-54.748*', '(33.123)'],
#        ['yngkid', '-13.962', '(50.341)'],
#        ['marr', '31.211', '(42.233)'],
#        ['Constant', '3450.913***', '(80.726)']], dtype='<U11')

# %%
df = pd.DataFrame(np.reshape (data_string.strip().split(),(8,3)), columns=['Name','Estimate','std.error'])
df
# Out:
#        Name     Estimate std.error
# 0    totwrk    -0.169***   (0.018)
# 1       age       2.689*   (1.469)
# 2     south    101.568**  (41.837)
# 3      male     87.669**  (35.104)
# 4      smsa     -54.748*  (33.123)
# 5    yngkid      -13.962  (50.341)
# 6      marr       31.211  (42.233)
# 7  Constant  3450.913***  (80.726)

# %%
df['Estimate_numb'] = df['Estimate'].str.extract(r'([-+]?\d+.\d+)').astype(float)
df['std_erro_numb'] = df['std.error'].str.extract(r'([-+]?\d+.\d+)').astype(float)
df
# Out:
#        Name     Estimate std.error  Estimate_numb  std_erro_numb
# 0    totwrk    -0.169***   (0.018)         -0.169          0.018
# 1       age       2.689*   (1.469)          2.689          1.469
# 2     south    101.568**  (41.837)        101.568         41.837
# 3      male     87.669**  (35.104)         87.669         35.104
# 4      smsa     -54.748*  (33.123)        -54.748         33.123
# 5    yngkid      -13.962  (50.341)        -13.962         50.341
# 6      marr       31.211  (42.233)         31.211         42.233
# 7  Constant  3450.913***  (80.726)       3450.913         80.726

# %%
alpha= 0.01
t_cr = stats.t.ppf(1-alpha/2, 706-7)
t_cr
# Out:
# 2.582881108461278

# %%
df['lower'] = (df['Estimate'] - df['Std.error']*t_cr).round(2)
df['upper'] = (df['Estimate'] + df['Std.error']*t_cr).round(2)
df
